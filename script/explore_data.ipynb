# %%
import pandas as pd 
import os

path = r'../'

# %%
df = pd.read_csv(os.path.join(path, 'og_data','us_state_death.csv'),index_col = False)

# %%
df.head()
# Out:
#   State_Territory  Total Cases  Confirmed Cases  Probable Cases  \
# 0          Alaska        39738              NaN             NaN
# 1         Alabama       295631         242830.0         52801.0
# 2        Arkansas       185702              NaN             NaN
# 3  American Samoa            3              NaN             NaN
# 4         Arizona       408442         392991.0         15451.0
#
#    Cases in Last 7 Days  Case Rate per 100000  Total Deaths  Confirmed Deaths  \
# 0                  4018                  5389           175               NaN
# 1                 25754                  6048          4102            3624.0
# 2                 14778                  6162          2945               NaN
# 3                     0                     5             0               NaN
# 4                 44166                  5695          7357            6779.0
#
#    Probable Deaths  Deaths in Last 7 Days  Death Rate per 100000  \
# ...

# %%
clean_df = df.loc[:2,['State_Territory','Total Cases','Case Rate per 100000', 'Total Deaths', 'Death Rate per 100000']]
clean_df.head()
# Out:
#   State_Territory  Total Cases  Case Rate per 100000  Total Deaths  \
# 0          Alaska        39738                  5389           175
# 1         Alabama       295631                  6048          4102
# 2        Arkansas       185702                  6162          2945
#
#    Death Rate per 100000
# 0                     23
# 1                     83
# 2                     97

# %%
write_csv = clean_df.to_csv(os.path.join(path,'Clean_data','cases_deaths.csv'))

# %%
df_test = pd.read_csv(os.path.join(path, 'Clean_data','cases_deaths.csv'),index_col = False)
df_test.head()
# Out:
#    Unnamed: 0 State_Territory  Total Cases  Case Rate per 100000  \
# 0           0          Alaska        39738                  5389
# 1           1         Alabama       295631                  6048
# 2           2        Arkansas       185702                  6162
#
#    Total Deaths  Death Rate per 100000
# 0           175                     23
# 1          4102                     83
# 2          2945                     97

# %%
df2 = pd.read_csv(os.path.join(path, 'og_data', 'reported_hospital_capacity_admissions_facility_level_weekly_average_timeseries_20201214.csv'), index_col = False)
df2.head()
# Out:
#   collection_week state     ccn                  hospital_name  \
# 0      2020-12-04    TX  452193          El Paso LTAC Hospital
# 1      2020-12-04    LA     NaN  Alexandria Emergency Hospital
# 2      2020-12-04    LA     NaN  Crescent City Surgical Centre
# 3      2020-12-04    LA     NaN      Surgery Center of Zachary
# 4      2020-12-04    NV     NaN           Elite Medical Center
#
#               address        city      zip hospital_subtype  fips_code  \
# 0                 NaN         NaN  79902.0        Long Term        NaN
# 1  5900 Coliseum Blvd  Alexandria  71303.0       Short Term        NaN
# 2                 NaN         NaN  70118.0       Short Term        NaN
# 3                 NaN         NaN  70791.0       Short Term        NaN
# 4    150 E Harmon Ave   Las Vegas  89109.0       Short Term        NaN
#
#    is_metro_micro  ...  \
# 0           False  ...
# 1           False  ...
# 2           False  ...
# 3           False  ...
# 4           False  ...
#
# ...
